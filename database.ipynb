# %%
import pickle, sys
sys.path.append('./database')
from persons import Person, Article, DataBase

# %%
def save_database():
    with open('./database/database.pickle', 'wb') as f:
        pickle.dump(database, f)
    print('Saved.')

# %%
# database = DataBase()
# with open('./database/database.pickle', 'wb') as f:
    # pickle.dump(database, f)

with open('./database/database.pickle', 'rb') as f:
    database = pickle.load(f)
save_database()
# Out:
# Saved.

# %%
database.add(['Melania Trump'], 'Melanie Trump')
database.add(['Donald Trump'], 'Donald Trump')
database.add(['Vladimir Putin'], 'Vladimir Putin')
database.add(['Alexei Navalny', 'Alexey Navalny'], 'Alexei Navalny')
database.add(['Angela Merkel'], 'Angela Merkel')
save_database()
database.add(['Elon Musk'], 'Ilon Musk')
database.add(['Jeff Bezos'], 'Jeffrey Bezos')
database.add(['Joe Biden'], 'Joseph Robinette Biden Jr.')
database.add(['Volodymyr Zelensky'], 'Volodymyr Oleksandrovych Zelensky')
database.add(['Mark Zuckerberg'], 'Mark Zuckerberg')
save_database()

database.add(['Alexander Lukashenko', 'Alyaksandr Lukashenka'], 'Alexander Grigoryevich Lukashenko')
database.add(['Tim Cook'], 'Timothy Donald Cook')
database.add(['Emmanuel Macron'], 'Emmanuel Jean-Michel Frédéric Macron')
database.add(['Xi Jinping'], 'xi jinging')
database.add(['Kim Jong-un'], 'Kim Jong')
save_database()
database.add(['Prince Harry'], 'Prince Harry, Duke of Sussex')
database.add(['Meghan Markle'], 'Meghan, Duchess of Sussex')
database.add(['Elizabeth II'], 'Elizabeth Alexandra Mary')
database.add(['Warren Buffett'], 'Warren Edward Buffett')
database.add(['Bill Gates'], 'William Henry Gates III')
save_database()

database.add(['Pope Francis'], 'Pope Francis')
database.add(['Mohammed bin Salman'], 'Mohammed bin Salman bin Abdulaziz Al Saud')
database.add(['Narendra Modi'], 'Narendra Damodardas Modi')
database.add(['Angelina Jolie'], 'Angelina Jolie')
database.add(['Leonardo DiCaprio'], 'Leonardo Wilhelm DiCaprio')
save_database()
database.add(['Johnny Depp'], 'John Christopher Depp II')
database.add(['Brad Pitt'], 'William Bradley Pitt')
database.add(['Julia Roberts'], 'Julia Fiona Roberts')
database.add(['Jennifer Aniston'], 'Jennifer Joanna Aniston')
database.add(['Robert Downey Jr'], 'Robert John Downey Jr.')
save_database()

database.add(['Boris Johnson'], 'Alexander Boris de Pfeffel Johnson')
database.add(['Sylvester Stallone'], 'Sylvester Enzio Stallone')
database.add(['Arnold Schwarzenegger'], 'Arnold Alois Schwarzenegger')
database.add(['Tom Cruise'], 'Thomas Cruise Mapother IV')
database.add(['Anne Hathaway'], 'Anne Jacqueline Hathaway')
save_database()
database.add(['JK Rowling'], 'Joanne Rowling')
database.add(['Daniel Radcliffe'], 'Daniel Jacob Radcliffe')
database.add(['Emma Watson'], 'Emma Charlotte Duerre Watson')
database.add(['Madonna'], 'Madonna Louise Ciccone')
database.add(['Taylor Swift'], 'Taylor Alison Swift')
save_database()

database.add(['Recep Tayyip Erdogan', 'Erdogan'], 'Recep Tayyip Erdoğan')
database.set_bio_from_file('Recep Tayyip Erdogan')
database.add(['George Floyd'], 'George Perry Floyd Jr.')
database.add(['Beyonce', 'Beyoncé'], 'Beyoncé Giselle Knowles-Carter')
database.add(['Jay-Z'], 'Shawn Corey Carter')
database.add(['Kim Kardashian'], 'Kimberly Noel Kardashian West')
save_database()
database.add(['Kanye West'], 'Kanye Omari West')
database.add(['Shakira'], 'Shakira Isabel Mebarak Ripoll')
database.add(['Gerard Pique', 'Gerard Piqué'], 'Gerard Piqué Bernabeu')
database.add(['Lady Gaga'], 'Stefani Joanne Angelina Germanotta')
database.add(['Jennifer Lopez'], 'Jennifer Lynn Lopez')
save_database()

database.add(['Adele'], 'Adele Laurie Blue Adkins')
database.add(['Lionel Messi'], 'Lionel Andrés Messi')
database.add(['Cristiano Ronaldo'], 'Cristiano Ronaldo dos Santos Aveiro')
database.add(['James Cameron'], 'James Francis Cameron')
database.add(['Steven Spielberg'], 'Steven Allan Spielberg')
save_database()
database.add(['Harvey Weinstein'], 'Harvey Weinstein')
database.add(['Eminem'], 'Marshall Bruce Mathers')
database.add(['Michael Jordan'], 'Michael Jeffrey Jordan')
database.add(['Mike Tyson'], 'Michael Gerard Tyson')
database.add(['Jack Ma'], 'Jack Ma Yun')
save_database()

database.add(['Barack Obama'], 'Barack Hussein Obama II')
database.add(['Ellen DeGeneres'], 'Ellen Lee DeGeneres')
database.add(['David Beckham'], 'David Robert Joseph Beckham')
database.add(['Quentin Tarantino'], 'Quentin Jerome Tarantino')
database.add(['Jackie Chan'], 'Chan Kong-sang')
save_database()
database.add(['George Clooney'], 'George Timothy Clooney')
database.add(['Will Smith'], 'Willard Carroll Smith Jr.')
database.add(['Stephen Hawking'], 'Stephen William Hawking')
database.add(['Justin Bieber'], 'Justin Drew Bieber')
database.add(['Selena Gomez'], 'Selena Marie Gomez')
save_database()

database.add(['Vladimir Potanin'], 'Vladimir Olegovich Potanin')
database.add(['Hillary Clinton'], 'Hillary Diane Rodham Clinton')
database.add(['The 14th Dalai Lama', '14th Dalai Lama', 'Tenzin Gyatso'], 'Tenzin Gyatso')
database.add(['Elton John'], 'Sir Elton Hercules John')
database.add(['Meryl Streep'], 'Mary Louise "Meryl" Streep')
save_database()
database.add(['Dwayne Johnson'], 'Dwayne Douglas Johnson')
database.add(['Daniel Craig'], 'Daniel Wroughton Craig')
database.add(['Justin Timberlake'], 'Justin Randall Timberlake')
database.add(['Stephen King'], 'Stephen Edwin King')
database.add(['Ed Sheeran'], 'Edward Christopher Sheeran')
save_database()

database.add(['Yuri Milner'], 'Yuri Borisovich (Bentsionovich) Milner')
database.add(['Lyubov Sobol'], 'Lyubov Eduardovna Sobol')
database.add(['Kira Yarmysh'], 'Kira Aleksandrovna Yarmysh')
database.add(['Natalia Poklonskaya'], 'Natalia Vladimirovna Poklonskaya')
database.add(['Petro Poroshenko'], 'Petro Oleksiyovych Poroshenko')
save_database()
database.add(['Igor Strelkov', 'Igor Girkin'], 'Igor Ivanovich Strelkov')
database.add(['Arkady Volozh'], 'Arkady Yurievich Volozh')
database.add(['Ilya Segalovich'], 'Ilya Valentinovich Segalovich')
database.add(['Vladimir Lisin'], 'Vladimir Sergeyevich Lisin')
database.add(['Leonid Mikhelson'], 'Leonid Viktorovich Mikhelson')
save_database()

database.add(['Alexei Mordashov', 'Alexey Mordashov'], 'Alexey Mordashov')
database.add(['Vagit Alekperov'], 'Vagit Yusufovich Alekperov')
database.add(['Gennady Timchenko'], 'Gennady Nikolayevich Timchenko')
database.add(['Alisher Usmanov'], 'Alisher Burkhanovich Usmanov')
database.add(['Mikhail Fridman', 'Mikhail Friedman'], 'Mikhail Maratovich Fridman')
save_database()
database.add(['Andrey Melnichenko'], 'Andrey Melnichenko (industrialist)')
database.add(['Roman Abramovich'], 'Roman Arkadyevich Abramovich')
database.add(['Mikhail Prokhorov'], 'Mikhail Dmitrievitch Prokhorov')
database.add(['Viktor Vekselberg'], 'Viktor Felixovich Vekselberg')
database.add(['Suleyman Kerimov'], 'Suleyman Abusaidovich Kerimov')
save_database()

database.add(['German Khan'], 'German Borisovich Khan')
database.add(['Dmitry Rybolovlev'], 'Dmitry Yevgenyevich Rybolovlev')
database.add(['Ramzan Kadyrov'], 'Ramzan Akhmadovich Kadyrov')
database.add(['Sergey Sobyanin', 'Sergei Sobyanin'], 'Sergey Semyonovich Sobyanin')
database.add(['Vladimir Zhirinovsky'], 'Vladimir Volfovich Zhirinovsky')
save_database()
database.add(['Gennady Zyuganov'], 'Gennady Andreyevich Zyuganov')
database.add(['Duncan Laurence'], 'Duncan de Moor')
database.add(['Netta Barzilai', 'Netta'], 'Netta Barzilai')
database.add(['Salvador Sobral'], 'Salvador Thiam Vilar Braamcamp Sobral')
database.add(['Jamala'], 'Susana Alimivna Jamaladinova')
save_database()

database.add(['Mans Zelmerlow', 'Måns Zelmerlöw'], 'Måns Petter Albert Sahlén Zelmerlöw')
database.add(['Conchita Wurst', 'Conchita'], 'Thomas Neuwirth')
database.add(['Maria Sharapova'], 'Maria Yuryevna Sharapova')
database.add(['Sergey Lavrov', 'Sergei Lavrov'], 'Sergey Viktorovich Lavrov')
database.add(['Sergey Shoygu', 'Sergei Shoygu'], 'Sergei Shoigu')
save_database()
database.add(['Dmitry Medvedev'], 'Dmitry Anatolyevich Medvedev')
database.add(['Grigori Perelman', 'Grigory Perelman'], 'Grigori Yakovlevich Perelman')
database.add(['Michael Atiyah'], 'Sir Michael Francis Atiyah')
database.add(['Nikol Pashinyan'], 'Nikol Vovayi Pashinyan')
database.add(['Pavel Durov'], 'Pavel Valerievich Durov')
save_database()

database.add(['Yevgeny Prigozhin'], 'Yevgeny Viktorovich Prigozhin')
database.add(['Mikheil Saakashvili'], 'Mikheil Saakashvili')
database.add(['Jennifer Lawrence'], 'Jennifer Shrader Lawrence')
database.add(['Sully Sullenberger', 'Sully'], 'Chesley Burnett "Sully" Sullenberger')
database.add(['Yulia Lipnitskaya', 'Julia Lipnitskaya'], 'Yulia Vyacheslavovna Lipnitskaya')
save_database()
database.add(['Adelina Sotnikova'], 'Adelina Dmitriyevna Sotnikova')
database.add(['Suzanne Collins'], 'Suzanne Collins')
database.add(['Ilham Aliyev'], 'Ilham Heydar oglu Aliyev')
database.add(['Maria Zakharova'], 'Maria Vladimirovna Zakharova')
database.add(['Vladimir Solovyov', 'Vladimir Soloviev'], 'Vladimir Rudolfovich Solovyov')
save_database()

database.add(['Vladimir Pozner'], 'Vladimir Vladimirovich Pozner')
database.add(['Dmitry Kiselyov', 'Dmitry Kiselev'], 'Dmitry Konstantinovich Kiselyov')
database.add(['Alexander Bortnikov'], 'Alexander Vasilyevich Bortnikov')
database.add(['Sviatlana Tsikhanouskaya', 'Svetlana Tikhanovskaya'], 'Sviatlana Heorhiyeuna Tsikhanouskaya')
database.add(['Maria Kalesnikava', 'Maria Kolesnikova'], 'maria kolesnikova')
save_database()
database.add(['Robert Mugabe'], 'Robert Gabriel Mugabe')
database.add(['Oleg Tinkov'], 'Oleg Tinkov')
database.add(['Guy Ritchie'], 'Guy Stuart Ritchie')
database.add(['Qasem Soleimani'], 'Qasem Soleimani')
database.add(['Larry King'], 'Lawrence Harvey Zeiger')
save_database()

database.add(['Oleg Deripaska'], 'Oleg Vladimirovich Deripaska')
database.add(['Mikhail Khodorkovsky'], 'Mikhail Borisovich Khodorkovsky')
database.add(['Sia'], 'Sia Kate Isobelle Furler')
database.add(['Alexei Venediktov', 'Alexey Venediktov'], 'Alexey Venediktov')
database.add(['Alexander Lebedev'], 'Alexander Yevgenievich Lebedev')
save_database()
database.add(['Eugene Kaspersky', 'Yevgeny Kaspersky'], 'Yevgeny Kaspersky')
database.add(['Sergey Brin'], 'Sergey Mikhaylovich Brin')
database.add(['Larry Page'], 'Lawrence Edward Page')
database.add(['Richard Branson'], 'Sir Richard Charles Nicholas Branson')
database.add(['Mike Pompeo'], 'Michael Richard Pompeo')
save_database()

database.add(['Arsenio Hall'], 'Arsenio Hall (born February 12, 1956)')
database.add(['Billie Eilish'], 'Billie Eilish Pirate Baird O\'Connell')
database.add(['Daniel Kaluuya'], 'Daniel Kaluuya')
database.add(['Stacey Abrams'], 'Stacey Yvonne Abrams')
database.add(['Ayanna Pressley'], 'Ayanna Soyini Pressley')
save_database()
database.add(['Cori Bush'], 'Cori Anika Bush')
database.add(['Ron Klain'], 'Ronald Alan Klain')
database.add(['Hunter Biden'], 'Robert Hunter Biden')
database.add(['Beau Biden'], 'Joseph Robinette "Beau" Biden')
database.add(['Doug Emhoff'], 'Douglas Craig Emhoff')
save_database()

database.add(['Sacha Baron Cohen'], 'Sacha Noam Baron Cohen')
database.add(['Carole Baskin'], 'Carole Baskin (née Stairs Jones; born June 6, 1961)')
database.add(['Amy Coney Barrett'], 'Amy Vivian Coney Barrett')
database.add(['Shinzo Abe'], 'Shinzo Abe')
database.add(['Larry Nassar'], 'Lawrence Gerard Nassar')
save_database()
database.add(['Kim Yo-jong'], '김여정')
database.add(['George Takei'], 'Takei')
database.add(['Naomi Osaka'], 'Naomi Osaka')
database.add(['Awkwafina'], 'Nora Lum')
database.add(['Ang Lee'], 'Ang Lee OBS')
save_database()

database.add(['Anthony Fauci'], 'Anthony Stephen Fauci')
database.add(['Andrew Cuomo'], 'Andrew Mark Cuomo')
database.add(['Samuel Little'], 'Samuel Little')
database.add(['Jeffrey Epstein'], 'Jeffrey Edward Epstein')
database.add(['Tulsi Gabbard'], 'Tulsi Gabbard')
save_database()
database.add(['Tulsi Gabbard'], 'Tulsi Gabbard')
database.add(['Julian Castro', 'Julián Castro'], 'Julián Castro')
database.add(['Tom Steyer'], 'Thomas Fahr Steyer')
database.add(['Andrew Yang'], 'Andrew M. Yang')
database.add(['Amy Klobuchar'], 'Amy Jean Klobuchar')
save_database()

database.add(['Beto O\'Rourke'], 'Robert Francis "Beto" O\'Rourke')
database.add(['Pete Buttigieg'], 'Peter Paul Montgomery Buttigieg')
database.add(['Greta Thunberg'], 'Greta Tintin Eleonora Ernman Thunberg')
database.add(['Garth Brooks'], 'Troyal Garth Brooks')
database.add(['Lisa Kudrow'], 'Lisa Valerie Kudrow')
save_database()
database.add(['Jeff Dunham'], 'Jeff Dunham')
database.add(['Maya Rudolph'], 'Maya Khabira Rudolph')
database.add(['David Hasselhoff'], 'David Michael Hasselhoff')
database.add(['Peggy Lipton'], 'Margaret Ann Lipton')
database.add(['Archie Harrison Mountbatten-Windsor'], 'Archie Harrison Mountbatten-Windsor')
database.add(['John Singleton'], 'John Daniel Singleton')
save_database()

database.add(['KJ Apa'], 'James Fitzgerald Apa')
database.add(['Felicity Huffman'], 'Felicity Kendall Huffman')
database.add(['Liam Hemsworth'], 'Liam Hemsworth')
database.add(['Kamala Harris'], 'Kamala Devi Harris')
database.add(['Danielle Steel'], 'Danielle Fernandes Dominique Schuelein-Steel')
save_database()
database.add(['Charlie Hunnam'], 'Charles Hunnam')
database.add(['Ruby Rose'], 'Ruby Rose Langenheim')
database.add(['Les Moonves'], 'Leslie Roy Moonves')
database.add(['Constance Wu'], 'Constance Wu (born March 22, 1982)')
database.add(['Sarah Huckabee Sanders'], 'Sarah Elizabeth Sanders')
save_database()

database.add(['Tessa Thompson'], 'Tessa Lynne Thompson')
database.add(['Lana Del Rey'], 'Elizabeth Woolridge Grant')
database.add(['Pete Davidson'], 'Peter Michael Davidson')
database.add(['JoJo Siwa'], 'Joelle Joanie "JoJo" Siwa')
database.add(['Brett Kavanaugh'], 'Brett Michael Kavanaugh')
save_database()
database.add(['Lily James'], 'Lily Chloe Ninette Thomson')
database.add(['Elizabeth Holmes'], 'Elizabeth Anne Holmes')
database.add(['Alexandria Ocasio-Cortez'], 'Alexandria Ocasio-Cortez')
database.add(['Selma Blair'], 'Selma Blair Beitner')
database.add(['Lili Reinhart'], 'Lili Pauline Reinhart')
save_database()

# database.remove(['Anna Shcherbakova'])
# Out:
# /www.bbc.com/news/live/world-europe-jersey-43320934/page/4', 'https://www.bbc.com/news/entertainment-arts-55844207', 'https://www.bbc.com/news/topics/cyelj62p45yt/naomi-campbell', 'https://www.bbc.com/news/av/entertainment-arts-48677904', 'https://www.bbc.com/news/entertainment-arts-39743552', 'https://www.bbc.com/news/world-europe-35491909', 'https://www.bbc.com/news/uk-england-suffolk-44129166?intlink_from_url=&link_location=live-reporting-story', 'https://www.bbc.com/news/entertainment-arts-48941104', 'https://www.bbc.com/news/entertainment-arts-30326431', 'https://www.bbc.com/news/newsbeat-44857367?obOrigUrl=true', 'https://www.bbc.com/news/uk-england-suffolk-43967334', 'https://www.bbc.com/news/uk-42628660', 'https://www.bbc.com/news/entertainment-arts-42731212', 'https://www.bbc.com/news/entertainment-arts-47553029', 'https://www.bbc.com/news/entertainment-arts-32032471', 'https://www.bbc.com/news/entertainment-arts-50642523', 'https://www.bbc.com/news/uk-england-suffolk-556526
# ...

# %%
with open('./database/database.pickle', 'wb') as f:
    pickle.dump(database, f)
print(len(database.persons))
# Out:
# 210

# %%
for person in database.persons:
    if "Archie Harrison Mountbatten-Windsor" in person.names:
        print(person.summary)
        print(len(person.articles), 'articles in dataset.')
        for article in person.articles:
            print(article.content)
            # input()
        print()
# Out:
# d editors into the full glare of the public spotlight. Meghan is suing the Mail on Sunday over a claim that it unlawfully published one of her private letters and Harry filed proceedings at the High Court against the owners of the Sun, the defunct News of the World, and the Daily Mirror, in relation to alleged phone-hacking. As such a dramatic year came to a close, the royal couple took an extended break from royal duties over Christmas, taking Archie to the Canadian province of British Columbia. It gave them time to mull over their next move and, within days of the start of a new decade, they dropped their bombshell announcement. Neither Harry's father, Prince Charles, nor his older brother, Prince William, with whom Harry has said he has "good days" and "bad days", were consulted. Harry and Meghan were, they told their Instagram followers, planning to leave their royal duties - and the royal purse - behind. They hope their next chapter, spent in North America as well as the UK, wil
# ...
